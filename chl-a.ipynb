# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/water.csv')

# %%
df
# Out:
#     year  month   tem    DO     TN     TP    DTN    DTP  Chl-a
# 0   2019      1   3.3  14.8  3.504  0.028  3.423  0.014   17.3
# 1   2019      2   4.3  13.6  3.317  0.026  3.155  0.008   24.4
# 2   2019      3   8.8  12.6  3.506  0.024  3.342  0.008   22.9
# 3   2019      4  13.2  11.0  2.652  0.017  2.529  0.006   14.1
# 4   2019      5  19.5   9.1  1.886  0.024  1.780  0.013   14.5
# 5   2019      6  23.3   7.6  1.691  0.024  1.624  0.018   11.0
# 6   2019      7  25.3   6.2  1.661  0.043  1.577  0.033    9.2
# 7   2019      8  28.3   6.5  1.672  0.030  1.543  0.021   25.1
# 8   2019      9  23.4   8.4  1.759  0.057  1.658  0.047   15.7
# 9   2019     10  19.0  10.1  2.829  0.079  2.676  0.061   21.5
# 10  2019     11  14.0  11.6  2.453  0.025  2.364  0.015   20.2
# 11  2019     12   7.5  13.8  2.442  0.028  2.337  0.014   44.6
# 12  2020      1   4.1  14.1  3.143  0.025  3.008  0.017   19.6
# 13  2020      2   5.6  14.1  3.539  0.032  3.365  0.020   28.5
# ...

# %%
X=list(range(0,53))
plt.plot(X,df['Chl-a'])

# %%
fig, ax1 = plt.subplots()
ax1.plot(X, df['Chl-a'], color = 'red', alpha = 0.5)

ax2 = ax1.twinx()
ax2.plot(X, df['DO'], color = 'blue', alpha = 0.5)

# %%
ig, ax1 = plt.subplots()
ax1.plot(X, df['Chl-a'], color = 'red', alpha = 0.5)

ax2 = ax1.twinx()
ax2.plot(X, df['TP'], color = 'blue', alpha = 0.5)

# %%
ig, ax1 = plt.subplots()
ax1.plot(X, df['Chl-a'], color = 'red', alpha = 0.5)

ax2 = ax1.twinx()
ax2.plot(X, df['TN'], color = 'blue', alpha = 0.5)

# %%
ig, ax1 = plt.subplots()
ax1.plot(X, df['Chl-a'], color = 'red', alpha = 0.5)

ax2 = ax1.twinx()
ax2.plot(X, df['DTN'], color = 'blue', alpha = 0.5)

# %%
ig, ax1 = plt.subplots()
ax1.plot(X, df['Chl-a'], color = 'red', alpha = 0.5)

ax2 = ax1.twinx()
ax2.plot(X, df['DTP'], color = 'blue', alpha = 0.5)

# %%
ig, ax1 = plt.subplots()
ax1.plot(X, df['Chl-a'], color = 'red', alpha = 0.5)

ax2 = ax1.twinx()
ax2.plot(X, df['tem'], color = 'blue', alpha = 0.5)

# %% [markdown]
# ---------------------------------------------------------------------------------------

# %%
df['test']=df['TN']*df['DTN']
ig, ax1 = plt.subplots()
ax1.plot(X, df['Chl-a'], color = 'red', alpha = 0.5)

ax2 = ax1.twinx()
ax2.plot(X, df['test'], color = 'blue', alpha = 0.5)
